# %% [markdown]
# <a href="https://colab.research.google.com/github/JelaniSJ/GLAB_Lesson385/blob/main/J_Spencer_Joe_myenv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Jelani Spencer-Joe: This point of GLAB 385.1.2 is to create a virtual environment w/ virtualenv. I used [Google Colab](https://colab.research.google.com/drive/1H2zgabuBjHno7f1fzYuw5NfG8nuF_y9L?usp=sharing) to complete this.

# %%
# Path and version numbers for python depend on operating system
# Use ! to run the command in the terminal
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.13.15

# %%
# install virtualenv
# !pip install virtualenv

# %%
# create a virtual environment named myenv
# !virtualenv myenv
# Out:
# created virtual environment CPython3.13.15.final.0-64-x86_64 in 288ms
#   creator CPython3Posix(dest=/content/myenv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, via=copy, app_data_dir=/root/.cache/virtualenv)
#     added seed packages: pip==26.2.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator,XonshActivator

# %%
# !source myenv/bin/activate
